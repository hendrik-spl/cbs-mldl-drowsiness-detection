# %% [markdown]
# ## Basic Setup

# %%
import os
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.layers import Dense, Flatten, Input, Dropout, BatchNormalization
from keras.models import Sequential, Model
from keras.optimizers import SGD
from keras.applications import MobileNetV2
from keras.regularizers import l2

os.chdir('../../../') # move three level up to the base path
from src.utils import load_and_preprocess_images, plot_history
from src.model_evaluation import evaluate_model
from src.plot_images import plot_images, plot_predictions, plot_false_positives, plot_false_negatives

# %%
# set the random seeds to make sure that the results are reproducible
SEED = 1234
np.random.seed(SEED)
random.seed(SEED)
tf.random.set_seed(SEED)
keras.utils.set_random_seed(SEED)

# %%
model_name = '0_real_eyes'
transfer_learning_stage = '0_last_layers'
repo_path = '/Users/hendriksippel/Documents/Repositories/cbs-mldl-drowsiness-detection'

realDataPath = repo_path + '/data/CEW_Data_Test_Train'
realTrainingPath = realDataPath + '/TrainingSet'
realTestPath = realDataPath + '/TestSet'

# %%
comment = "afternoon run"
model_file_path = repo_path + f"/models/cnn/{model_name}/{transfer_learning_stage}/weights/{comment}_model.keras"
ckpt_file_path = repo_path + f"/models/cnn/{model_name}/{transfer_learning_stage}/ckpt/{comment}_checkpoint.model.keras"
history_file_path = repo_path + f"/models/cnn/{model_name}/{transfer_learning_stage}/history/{comment}_history.csv"
assert not os.path.exists(ckpt_file_path), "Model already exists. Please change the comment."

# %%
# Hyperparameters
BATCH_SIZE = 64
IMAGE_SIZE = (224, 224)
INPUT_SHAPE = IMAGE_SIZE + (3,)

MN_OUTPUT_LAYER = 'block_16_project_BN'
UNFREEZE_FROM_LAYER = 'block_16_project_BN'
DATA_AUG_RATE = 0.1
EPOCHS = 100
REGULARIZATION = 0.01
DROPOUT = 0.3
LEARNING_RATE = 0.0001
LOSS_FUNCTION = 'sparse_categorical_crossentropy'
OPTIMIZER = SGD(learning_rate=LEARNING_RATE)

# %%
early_stop = EarlyStopping(monitor="val_accuracy", mode="max", patience=20, start_from_epoch=10)
checkpoint = ModelCheckpoint(ckpt_file_path, monitor="val_accuracy", mode="max", save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_lr=0.00001, verbose=1)

# %%
real_train_data = load_and_preprocess_images(realTrainingPath, batch_size=BATCH_SIZE, image_size=IMAGE_SIZE, seed=SEED, data_aug_rate=DATA_AUG_RATE, subset='training', validation_split=0.2)
real_valid_data = load_and_preprocess_images(realTrainingPath, batch_size=BATCH_SIZE, image_size=IMAGE_SIZE, seed=SEED, subset='validation', validation_split=0.2)
real_test_data = load_and_preprocess_images(realTestPath, batch_size=BATCH_SIZE, image_size=IMAGE_SIZE, seed=SEED, shuffle=False)
# Out:
# Found 3876 files belonging to 2 classes.
# Using 3101 files for training.
# Found 3876 files belonging to 2 classes.
# Using 775 files for validation.
# Found 970 files belonging to 2 classes.

# %% [markdown]
# ## Training the Pre-Trained Model

# %%
def initialize_baseline_model(title, mn_output_layer, unfreeze_from_layer, loss_function, optimizer, dropout_rate, regularization_rate, input_shape=INPUT_SHAPE):

    # Load the MobileNetV2 model    
    pretrained_model = MobileNetV2(input_shape=input_shape, include_top=False, weights='imagenet')

    pretrained_model.trainable = False

    # Unfreeze the layers starting from unfreeze_from_layer (exclusive)
    unfreeze = False
    for layer in pretrained_model.layers:
        if unfreeze:
            layer.trainable = True
        elif layer.name == unfreeze_from_layer:
            layer.trainable = False
            unfreeze = True

    # Ensure BN layers are in inference mode
    for layer in pretrained_model.layers:
        if isinstance(layer, BatchNormalization):
            layer.trainable = False
        
    # Get the desired output layer
    last_layer = pretrained_model.get_layer(mn_output_layer)
    base_model = Model(inputs=pretrained_model.input, outputs=last_layer.output)

    # Functional API model construction
    x = base_model.output
    x = Flatten()(x)
    x = Dense(256, activation='relu', kernel_regularizer=l2(regularization_rate))(x)
    x = BatchNormalization()(x)
    x = Dropout(dropout_rate)(x)
    x = Dense(128, activation='relu', kernel_regularizer=l2(regularization_rate))(x)
    x = BatchNormalization()(x)
    x = Dropout(dropout_rate)(x)
    outputs = Dense(2, activation='softmax')(x)
    
    # Define the final model
    model = Model(inputs=base_model.input, outputs=outputs, name=title)

    # Compile the model
    model.compile(loss=loss_function, optimizer=optimizer, metrics=['accuracy'])

    return model

# %%
model = initialize_baseline_model(title=model_name, mn_output_layer=MN_OUTPUT_LAYER, unfreeze_from_layer=UNFREEZE_FROM_LAYER, loss_function=LOSS_FUNCTION, optimizer=OPTIMIZER, dropout_rate=DROPOUT, regularization_rate=REGULARIZATION)

# %%
model.summary(show_trainable=True)
# Out:
# Model: "0_baseline_cnn"
# ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)      ┃ Output Shape    ┃   Param # ┃ Connected to   ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer_6     │ (None, 224,     │         0 │ -              │   -   │
# │ (InputLayer)      │ 224, 3)         │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ Conv1 (Conv2D)    │ (None, 112,     │       864 │ input_layer_6… │   N   │
# │                   │ 112, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ bn_Conv1          │ (None, 112,     │       128 │ Conv1[0][0]    │   N   │
# │ (BatchNormalizat… │ 112, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ Conv1_relu (ReLU) │ (None, 112,     │         0 │ bn_Conv1[0][0] │   -   │
# │                   │ 112, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_de… │ (None, 112,     │       288 │ Conv1_relu[0]… │   N   │
# │ (DepthwiseConv2D) │ 112, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_de… │ (None, 112,     │       128 │ expanded_conv… │   N   │
# │ (BatchNormalizat… │ 112, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_de… │ (None, 112,     │         0 │ expanded_conv… │   -   │
# │ (ReLU)            │ 112, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_pr… │ (None, 112,     │       512 │ expanded_conv… │   N   │
# │ (Conv2D)          │ 112, 16)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_pr… │ (None, 112,     │        64 │ expanded_conv… │   N   │
# │ (BatchNormalizat… │ 112, 16)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_1_expand    │ (None, 112,     │     1,536 │ expanded_conv… │   N   │
# │ (Conv2D)          │ 112, 96)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_1_expand_BN │ (None, 112,     │       384 │ block_1_expan… │   N   │
# │ (BatchNormalizat… │ 112, 96)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_1_expand_r… │ (None, 112,     │         0 │ block_1_expan… │   -   │
# │ (ReLU)            │ 112, 96)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_1_pad       │ (None, 113,     │         0 │ block_1_expan… │   -   │
# │ (ZeroPadding2D)   │ 113, 96)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_1_depthwise │ (None, 56, 56,  │       864 │ block_1_pad[0… │   N   │
# │ (DepthwiseConv2D) │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_1_depthwis… │ (None, 56, 56,  │       384 │ block_1_depth… │   N   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_1_depthwis… │ (None, 56, 56,  │         0 │ block_1_depth… │   -   │
# │ (ReLU)            │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_1_project   │ (None, 56, 56,  │     2,304 │ block_1_depth… │   N   │
# │ (Conv2D)          │ 24)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_1_project_… │ (None, 56, 56,  │        96 │ block_1_proje… │   N   │
# │ (BatchNormalizat… │ 24)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_2_expand    │ (None, 56, 56,  │     3,456 │ block_1_proje… │   N   │
# │ (Conv2D)          │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_2_expand_BN │ (None, 56, 56,  │       576 │ block_2_expan… │   N   │
# │ (BatchNormalizat… │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_2_expand_r… │ (None, 56, 56,  │         0 │ block_2_expan… │   -   │
# │ (ReLU)            │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_2_depthwise │ (None, 56, 56,  │     1,296 │ block_2_expan… │   N   │
# │ (DepthwiseConv2D) │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_2_depthwis… │ (None, 56, 56,  │       576 │ block_2_depth… │   N   │
# │ (BatchNormalizat… │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_2_depthwis… │ (None, 56, 56,  │         0 │ block_2_depth… │   -   │
# │ (ReLU)            │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_2_project   │ (None, 56, 56,  │     3,456 │ block_2_depth… │   N   │
# │ (Conv2D)          │ 24)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_2_project_… │ (None, 56, 56,  │        96 │ block_2_proje… │   N   │
# │ (BatchNormalizat… │ 24)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_2_add (Add) │ (None, 56, 56,  │         0 │ block_1_proje… │   -   │
# │                   │ 24)             │           │ block_2_proje… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_3_expand    │ (None, 56, 56,  │     3,456 │ block_2_add[0… │   N   │
# │ (Conv2D)          │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_3_expand_BN │ (None, 56, 56,  │       576 │ block_3_expan… │   N   │
# │ (BatchNormalizat… │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_3_expand_r… │ (None, 56, 56,  │         0 │ block_3_expan… │   -   │
# │ (ReLU)            │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_3_pad       │ (None, 57, 57,  │         0 │ block_3_expan… │   -   │
# │ (ZeroPadding2D)   │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_3_depthwise │ (None, 28, 28,  │     1,296 │ block_3_pad[0… │   N   │
# │ (DepthwiseConv2D) │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_3_depthwis… │ (None, 28, 28,  │       576 │ block_3_depth… │   N   │
# │ (BatchNormalizat… │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_3_depthwis… │ (None, 28, 28,  │         0 │ block_3_depth… │   -   │
# │ (ReLU)            │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_3_project   │ (None, 28, 28,  │     4,608 │ block_3_depth… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_3_project_… │ (None, 28, 28,  │       128 │ block_3_proje… │   N   │
# │ (BatchNormalizat… │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_4_expand    │ (None, 28, 28,  │     6,144 │ block_3_proje… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_4_expand_BN │ (None, 28, 28,  │       768 │ block_4_expan… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_4_expand_r… │ (None, 28, 28,  │         0 │ block_4_expan… │   -   │
# │ (ReLU)            │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_4_depthwise │ (None, 28, 28,  │     1,728 │ block_4_expan… │   N   │
# │ (DepthwiseConv2D) │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_4_depthwis… │ (None, 28, 28,  │       768 │ block_4_depth… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_4_depthwis… │ (None, 28, 28,  │         0 │ block_4_depth… │   -   │
# │ (ReLU)            │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_4_project   │ (None, 28, 28,  │     6,144 │ block_4_depth… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_4_project_… │ (None, 28, 28,  │       128 │ block_4_proje… │   N   │
# │ (BatchNormalizat… │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_4_add (Add) │ (None, 28, 28,  │         0 │ block_3_proje… │   -   │
# │                   │ 32)             │           │ block_4_proje… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_5_expand    │ (None, 28, 28,  │     6,144 │ block_4_add[0… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_5_expand_BN │ (None, 28, 28,  │       768 │ block_5_expan… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_5_expand_r… │ (None, 28, 28,  │         0 │ block_5_expan… │   -   │
# │ (ReLU)            │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_5_depthwise │ (None, 28, 28,  │     1,728 │ block_5_expan… │   N   │
# │ (DepthwiseConv2D) │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_5_depthwis… │ (None, 28, 28,  │       768 │ block_5_depth… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_5_depthwis… │ (None, 28, 28,  │         0 │ block_5_depth… │   -   │
# │ (ReLU)            │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_5_project   │ (None, 28, 28,  │     6,144 │ block_5_depth… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_5_project_… │ (None, 28, 28,  │       128 │ block_5_proje… │   N   │
# │ (BatchNormalizat… │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_5_add (Add) │ (None, 28, 28,  │         0 │ block_4_add[0… │   -   │
# │                   │ 32)             │           │ block_5_proje… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_6_expand    │ (None, 28, 28,  │     6,144 │ block_5_add[0… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_6_expand_BN │ (None, 28, 28,  │       768 │ block_6_expan… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_6_expand_r… │ (None, 28, 28,  │         0 │ block_6_expan… │   -   │
# │ (ReLU)            │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_6_pad       │ (None, 29, 29,  │         0 │ block_6_expan… │   -   │
# │ (ZeroPadding2D)   │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_6_depthwise │ (None, 14, 14,  │     1,728 │ block_6_pad[0… │   N   │
# │ (DepthwiseConv2D) │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_6_depthwis… │ (None, 14, 14,  │       768 │ block_6_depth… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_6_depthwis… │ (None, 14, 14,  │         0 │ block_6_depth… │   -   │
# │ (ReLU)            │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_6_project   │ (None, 14, 14,  │    12,288 │ block_6_depth… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_6_project_… │ (None, 14, 14,  │       256 │ block_6_proje… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_7_expand    │ (None, 14, 14,  │    24,576 │ block_6_proje… │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_7_expand_BN │ (None, 14, 14,  │     1,536 │ block_7_expan… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_7_expand_r… │ (None, 14, 14,  │         0 │ block_7_expan… │   -   │
# │ (ReLU)            │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_7_depthwise │ (None, 14, 14,  │     3,456 │ block_7_expan… │   N   │
# │ (DepthwiseConv2D) │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_7_depthwis… │ (None, 14, 14,  │     1,536 │ block_7_depth… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_7_depthwis… │ (None, 14, 14,  │         0 │ block_7_depth… │   -   │
# │ (ReLU)            │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_7_project   │ (None, 14, 14,  │    24,576 │ block_7_depth… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_7_project_… │ (None, 14, 14,  │       256 │ block_7_proje… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_7_add (Add) │ (None, 14, 14,  │         0 │ block_6_proje… │   -   │
# │                   │ 64)             │           │ block_7_proje… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_8_expand    │ (None, 14, 14,  │    24,576 │ block_7_add[0… │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_8_expand_BN │ (None, 14, 14,  │     1,536 │ block_8_expan… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_8_expand_r… │ (None, 14, 14,  │         0 │ block_8_expan… │   -   │
# │ (ReLU)            │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_8_depthwise │ (None, 14, 14,  │     3,456 │ block_8_expan… │   N   │
# │ (DepthwiseConv2D) │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_8_depthwis… │ (None, 14, 14,  │     1,536 │ block_8_depth… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_8_depthwis… │ (None, 14, 14,  │         0 │ block_8_depth… │   -   │
# │ (ReLU)            │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_8_project   │ (None, 14, 14,  │    24,576 │ block_8_depth… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_8_project_… │ (None, 14, 14,  │       256 │ block_8_proje… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_8_add (Add) │ (None, 14, 14,  │         0 │ block_7_add[0… │   -   │
# │                   │ 64)             │           │ block_8_proje… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_9_expand    │ (None, 14, 14,  │    24,576 │ block_8_add[0… │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_9_expand_BN │ (None, 14, 14,  │     1,536 │ block_9_expan… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_9_expand_r… │ (None, 14, 14,  │         0 │ block_9_expan… │   -   │
# │ (ReLU)            │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_9_depthwise │ (None, 14, 14,  │     3,456 │ block_9_expan… │   N   │
# │ (DepthwiseConv2D) │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_9_depthwis… │ (None, 14, 14,  │     1,536 │ block_9_depth… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_9_depthwis… │ (None, 14, 14,  │         0 │ block_9_depth… │   -   │
# │ (ReLU)            │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_9_project   │ (None, 14, 14,  │    24,576 │ block_9_depth… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_9_project_… │ (None, 14, 14,  │       256 │ block_9_proje… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_9_add (Add) │ (None, 14, 14,  │         0 │ block_8_add[0… │   -   │
# │                   │ 64)             │           │ block_9_proje… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_10_expand   │ (None, 14, 14,  │    24,576 │ block_9_add[0… │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_10_expand_… │ (None, 14, 14,  │     1,536 │ block_10_expa… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_10_expand_… │ (None, 14, 14,  │         0 │ block_10_expa… │   -   │
# │ (ReLU)            │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_10_depthwi… │ (None, 14, 14,  │     3,456 │ block_10_expa… │   N   │
# │ (DepthwiseConv2D) │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_10_depthwi… │ (None, 14, 14,  │     1,536 │ block_10_dept… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_10_depthwi… │ (None, 14, 14,  │         0 │ block_10_dept… │   -   │
# │ (ReLU)            │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_10_project  │ (None, 14, 14,  │    36,864 │ block_10_dept… │   N   │
# │ (Conv2D)          │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_10_project… │ (None, 14, 14,  │       384 │ block_10_proj… │   N   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_11_expand   │ (None, 14, 14,  │    55,296 │ block_10_proj… │   N   │
# │ (Conv2D)          │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_11_expand_… │ (None, 14, 14,  │     2,304 │ block_11_expa… │   N   │
# │ (BatchNormalizat… │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_11_expand_… │ (None, 14, 14,  │         0 │ block_11_expa… │   -   │
# │ (ReLU)            │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_11_depthwi… │ (None, 14, 14,  │     5,184 │ block_11_expa… │   N   │
# │ (DepthwiseConv2D) │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_11_depthwi… │ (None, 14, 14,  │     2,304 │ block_11_dept… │   N   │
# │ (BatchNormalizat… │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_11_depthwi… │ (None, 14, 14,  │         0 │ block_11_dept… │   -   │
# │ (ReLU)            │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_11_project  │ (None, 14, 14,  │    55,296 │ block_11_dept… │   N   │
# │ (Conv2D)          │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_11_project… │ (None, 14, 14,  │       384 │ block_11_proj… │   N   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_11_add      │ (None, 14, 14,  │         0 │ block_10_proj… │   -   │
# │ (Add)             │ 96)             │           │ block_11_proj… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_12_expand   │ (None, 14, 14,  │    55,296 │ block_11_add[… │   N   │
# │ (Conv2D)          │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_12_expand_… │ (None, 14, 14,  │     2,304 │ block_12_expa… │   N   │
# │ (BatchNormalizat… │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_12_expand_… │ (None, 14, 14,  │         0 │ block_12_expa… │   -   │
# │ (ReLU)            │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_12_depthwi… │ (None, 14, 14,  │     5,184 │ block_12_expa… │   N   │
# │ (DepthwiseConv2D) │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_12_depthwi… │ (None, 14, 14,  │     2,304 │ block_12_dept… │   N   │
# │ (BatchNormalizat… │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_12_depthwi… │ (None, 14, 14,  │         0 │ block_12_dept… │   -   │
# │ (ReLU)            │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_12_project  │ (None, 14, 14,  │    55,296 │ block_12_dept… │   N   │
# │ (Conv2D)          │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_12_project… │ (None, 14, 14,  │       384 │ block_12_proj… │   N   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_12_add      │ (None, 14, 14,  │         0 │ block_11_add[… │   -   │
# │ (Add)             │ 96)             │           │ block_12_proj… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_13_expand   │ (None, 14, 14,  │    55,296 │ block_12_add[… │   N   │
# │ (Conv2D)          │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_13_expand_… │ (None, 14, 14,  │     2,304 │ block_13_expa… │   N   │
# │ (BatchNormalizat… │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_13_expand_… │ (None, 14, 14,  │         0 │ block_13_expa… │   -   │
# │ (ReLU)            │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_13_pad      │ (None, 15, 15,  │         0 │ block_13_expa… │   -   │
# │ (ZeroPadding2D)   │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_13_depthwi… │ (None, 7, 7,    │     5,184 │ block_13_pad[… │   N   │
# │ (DepthwiseConv2D) │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_13_depthwi… │ (None, 7, 7,    │     2,304 │ block_13_dept… │   N   │
# │ (BatchNormalizat… │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_13_depthwi… │ (None, 7, 7,    │         0 │ block_13_dept… │   -   │
# │ (ReLU)            │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_13_project  │ (None, 7, 7,    │    92,160 │ block_13_dept… │   N   │
# │ (Conv2D)          │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_13_project… │ (None, 7, 7,    │       640 │ block_13_proj… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_14_expand   │ (None, 7, 7,    │   153,600 │ block_13_proj… │   N   │
# │ (Conv2D)          │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_14_expand_… │ (None, 7, 7,    │     3,840 │ block_14_expa… │   N   │
# │ (BatchNormalizat… │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_14_expand_… │ (None, 7, 7,    │         0 │ block_14_expa… │   -   │
# │ (ReLU)            │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_14_depthwi… │ (None, 7, 7,    │     8,640 │ block_14_expa… │   N   │
# │ (DepthwiseConv2D) │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_14_depthwi… │ (None, 7, 7,    │     3,840 │ block_14_dept… │   N   │
# │ (BatchNormalizat… │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_14_depthwi… │ (None, 7, 7,    │         0 │ block_14_dept… │   -   │
# │ (ReLU)            │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_14_project  │ (None, 7, 7,    │   153,600 │ block_14_dept… │   N   │
# │ (Conv2D)          │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_14_project… │ (None, 7, 7,    │       640 │ block_14_proj… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_14_add      │ (None, 7, 7,    │         0 │ block_13_proj… │   -   │
# │ (Add)             │ 160)            │           │ block_14_proj… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_15_expand   │ (None, 7, 7,    │   153,600 │ block_14_add[… │   N   │
# │ (Conv2D)          │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_15_expand_… │ (None, 7, 7,    │     3,840 │ block_15_expa… │   N   │
# │ (BatchNormalizat… │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_15_expand_… │ (None, 7, 7,    │         0 │ block_15_expa… │   -   │
# │ (ReLU)            │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_15_depthwi… │ (None, 7, 7,    │     8,640 │ block_15_expa… │   N   │
# │ (DepthwiseConv2D) │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_15_depthwi… │ (None, 7, 7,    │     3,840 │ block_15_dept… │   N   │
# │ (BatchNormalizat… │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_15_depthwi… │ (None, 7, 7,    │         0 │ block_15_dept… │   -   │
# │ (ReLU)            │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_15_project  │ (None, 7, 7,    │   153,600 │ block_15_dept… │   N   │
# │ (Conv2D)          │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_15_project… │ (None, 7, 7,    │       640 │ block_15_proj… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_15_add      │ (None, 7, 7,    │         0 │ block_14_add[… │   -   │
# │ (Add)             │ 160)            │           │ block_15_proj… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_16_expand   │ (None, 7, 7,    │   153,600 │ block_15_add[… │   N   │
# │ (Conv2D)          │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_16_expand_… │ (None, 7, 7,    │     3,840 │ block_16_expa… │   N   │
# │ (BatchNormalizat… │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_16_expand_… │ (None, 7, 7,    │         0 │ block_16_expa… │   -   │
# │ (ReLU)            │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_16_depthwi… │ (None, 7, 7,    │     8,640 │ block_16_expa… │   N   │
# │ (DepthwiseConv2D) │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_16_depthwi… │ (None, 7, 7,    │     3,840 │ block_16_dept… │   N   │
# │ (BatchNormalizat… │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_16_depthwi… │ (None, 7, 7,    │         0 │ block_16_dept… │   -   │
# │ (ReLU)            │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_16_project  │ (None, 7, 7,    │   307,200 │ block_16_dept… │   N   │
# │ (Conv2D)          │ 320)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_16_project… │ (None, 7, 7,    │     1,280 │ block_16_proj… │   N   │
# │ (BatchNormalizat… │ 320)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ flatten_1         │ (None, 15680)   │         0 │ block_16_proj… │   -   │
# │ (Flatten)         │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_3 (Dense)   │ (None, 256)     │ 4,014,336 │ flatten_1[0][… │   Y   │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 256)     │     1,024 │ dense_3[0][0]  │   Y   │
# │ (BatchNormalizat… │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dropout_2         │ (None, 256)     │         0 │ batch_normali… │   -   │
# │ (Dropout)         │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_4 (Dense)   │ (None, 128)     │    32,896 │ dropout_2[0][… │   Y   │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 128)     │       512 │ dense_4[0][0]  │   Y   │
# │ (BatchNormalizat… │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dropout_3         │ (None, 128)     │         0 │ batch_normali… │   -   │
# │ (Dropout)         │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_5 (Dense)   │ (None, 2)       │       258 │ dropout_3[0][… │   Y   │
# └───────────────────┴─────────────────┴───────────┴────────────────┴───────┘
#  Total params: 5,892,290 (22.48 MB)
#  Trainable params: 4,048,258 (15.44 MB)
#  Non-trainable params: 1,844,032 (7.03 MB)

# %%
history = model.fit(
    real_train_data,
    validation_data=real_valid_data,
    epochs=EPOCHS,
    callbacks=[early_stop, checkpoint, reduce_lr]
    )
# Out:
# Epoch 1/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4690 - loss: 8.0519
# Epoch 1: val_accuracy improved from -inf to 0.75871, saving model to /Users/hendriksippel/Documents/Repositories/cbs-mldl-drowsiness-detection/models/0_baseline_cnn/ckpt/afternoon run_checkpoint.model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 78s 2s/step - accuracy: 0.4700 - loss: 8.0486 - val_accuracy: 0.7587 - val_loss: 7.2510 - learning_rate: 1.0000e-04
# Epoch 2/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6591 - loss: 7.5181
# Epoch 2: val_accuracy improved from 0.75871 to 0.81806, saving model to /Users/hendriksippel/Documents/Repositories/cbs-mldl-drowsiness-detection/models/0_baseline_cnn/ckpt/afternoon run_checkpoint.model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 84s 2s/step - accuracy: 0.6597 - loss: 7.5167 - val_accuracy: 0.8181 - val_loss: 7.1410 - learning_rate: 1.0000e-04
# Epoch 3/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7607 - loss: 7.2924
# Epoch 3: val_accuracy improved from 0.81806 to 0.84903, saving model to /Users/hendriksippel/Documents/Repositories/cbs-mldl-drowsiness-detection/models/0_baseline_cnn/ckpt/afternoon run_checkpoint.model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.7610 - loss: 7.2920 - val_accuracy: 0.8490 - val_loss: 7.0793 - learning_rate: 1.0000e-04
# Epoch 4/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7974 - loss: 7.2041
# Epoch 4: val_accuracy improved from 0.84903 to 0.86839, saving model to /Users/hendriksippel/Documents/Repositories/cbs-mldl-drowsiness-detection/models/0_baseline_cnn/ckpt/afternoon run_checkpoint.model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.7976 - loss: 7.2039 - val_accuracy: 0.8684 - val_loss: 7.0452 - learning_rate: 1.0000e-04
# Epoch 5/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8233 - loss: 7.1707
# Epoch 5: val_accuracy improved from 0.86839 to 0.87097, saving model to /Users/hendriksippel/Documents/Repositories/cbs-mldl-drowsiness-detection/models/0_baseline_cnn/ckpt/afternoon run_checkpoint.model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 79s 2s/step - accuracy: 0.8235 - loss: 7.1704 - val_accuracy: 0.8710 - val_loss: 7.0241 - learning_rate: 1.0000e-04
# Epoch 6/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8430 - loss: 7.1264
# Epoch 6: val_accuracy improved from 0.87097 to 0.88000, saving model to /Users/hendriksippel/Documents/Repositories/cbs-mldl-drowsiness-detection/models/0_baseline_cnn/ckpt/afternoon run_checkpoint.model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.8431 - loss: 7.1261 - val_accuracy: 0.8800 - val_loss: 7.0101 - learning_rate: 1.0000e-04
# Epoch 7/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8528 - loss: 7.0970
# Epoch 7: val_accuracy improved from 0.88000 to 0.89032, saving model to /Users/hendriksippel/Documents/Repositories/cbs-mldl-drowsiness-detection/models/0_baseline_cnn/ckpt/afternoon run_checkpoint.model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.8529 - loss: 7.0967 - val_accuracy: 0.8903 - val_loss: 6.9973 - learning_rate: 1.0000e-04
# Epoch 8/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8649 - loss: 7.0561
# Epoch 8: val_accuracy did not improve from 0.89032
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.8650 - loss: 7.0562 - val_accuracy: 0.8890 - val_loss: 6.9876 - learning_rate: 1.0000e-04
# Epoch 9/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8756 - loss: 7.0374
# Epoch 9: val_accuracy improved from 0.89032 to 0.89677, saving model to /Users/hendriksippel/Documents/Repositories/cbs-mldl-drowsiness-detection/models/0_baseline_cnn/ckpt/afternoon run_checkpoint.model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.8756 - loss: 7.0373 - val_accuracy: 0.8968 - val_loss: 6.9794 - learning_rate: 1.0000e-04
# Epoch 10/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8793 - loss: 7.0295
# Epoch 10: val_accuracy improved from 0.89677 to 0.90452, saving model to /Users/hendriksippel/Documents/Repositories/cbs-mldl-drowsiness-detection/models/0_baseline_cnn/ckpt/afternoon run_checkpoint.model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.8794 - loss: 7.0292 - val_accuracy: 0.9045 - val_loss: 6.9720 - learning_rate: 1.0000e-04
# Epoch 11/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8816 - loss: 7.0397
# Epoch 11: val_accuracy improved from 0.90452 to 0.90581, saving model to /Users/hendriksippel/Documents/Repositories/cbs-mldl-drowsiness-detection/models/0_baseline_cnn/ckpt/afternoon run_checkpoint.model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.8816 - loss: 7.0392 - val_accuracy: 0.9058 - val_loss: 6.9656 - learning_rate: 1.0000e-04
# Epoch 12/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8895 - loss: 7.0101
# Epoch 12: val_accuracy improved from 0.90581 to 0.91097, saving model to /Users/hendriksippel/Documents/Repositories/cbs-mldl-drowsiness-detection/models/0_baseline_cnn/ckpt/afternoon run_checkpoint.model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.8897 - loss: 7.0097 - val_accuracy: 0.9110 - val_loss: 6.9604 - learning_rate: 1.0000e-04
# Epoch 13/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8863 - loss: 6.9909
# Epoch 13: val_accuracy improved from 0.91097 to 0.91871, saving model to /Users/hendriksippel/Documents/Repositories/cbs-mldl-drowsiness-detection/models/0_baseline_cnn/ckpt/afternoon run_checkpoint.model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.8864 - loss: 6.9908 - val_accuracy: 0.9187 - val_loss: 6.9548 - learning_rate: 1.0000e-04
# Epoch 14/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8871 - loss: 7.0104
# Epoch 14: val_accuracy did not improve from 0.91871
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.8872 - loss: 7.0100 - val_accuracy: 0.9174 - val_loss: 6.9491 - learning_rate: 1.0000e-04
# Epoch 15/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9112 - loss: 6.9650
# Epoch 15: val_accuracy did not improve from 0.91871
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.9112 - loss: 6.9649 - val_accuracy: 0.9148 - val_loss: 6.9470 - learning_rate: 1.0000e-04
# Epoch 16/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9024 - loss: 6.9601
# Epoch 16: val_accuracy did not improve from 0.91871
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.9026 - loss: 6.9599 - val_accuracy: 0.9148 - val_loss: 6.9425 - learning_rate: 1.0000e-04
# Epoch 17/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9133 - loss: 6.9513
# Epoch 17: val_accuracy did not improve from 0.91871
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.9134 - loss: 6.9511 - val_accuracy: 0.9187 - val_loss: 6.9382 - learning_rate: 1.0000e-04
# Epoch 18/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9046 - loss: 6.9566
# Epoch 18: val_accuracy improved from 0.91871 to 0.92000, saving model to /Users/hendriksippel/Documents/Repositories/cbs-mldl-drowsiness-detection/models/0_baseline_cnn/ckpt/afternoon run_checkpoint.model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.9048 - loss: 6.9564 - val_accuracy: 0.9200 - val_loss: 6.9328 - learning_rate: 1.0000e-04
# Epoch 19/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9091 - loss: 6.9385
# Epoch 19: val_accuracy did not improve from 0.92000
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 78s 2s/step - accuracy: 0.9092 - loss: 6.9385 - val_accuracy: 0.9187 - val_loss: 6.9294 - learning_rate: 1.0000e-04
# Epoch 20/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9222 - loss: 6.9197
# Epoch 20: val_accuracy did not improve from 0.92000
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.9221 - loss: 6.9197 - val_accuracy: 0.9174 - val_loss: 6.9269 - learning_rate: 1.0000e-04
# Epoch 21/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9162 - loss: 6.9263
# Epoch 21: val_accuracy did not improve from 0.92000
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.9163 - loss: 6.9261 - val_accuracy: 0.9200 - val_loss: 6.9241 - learning_rate: 1.0000e-04
# Epoch 22/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9171 - loss: 6.9323
# Epoch 22: val_accuracy improved from 0.92000 to 0.92258, saving model to /Users/hendriksippel/Documents/Repositories/cbs-mldl-drowsiness-detection/models/0_baseline_cnn/ckpt/afternoon run_checkpoint.model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.9172 - loss: 6.9320 - val_accuracy: 0.9226 - val_loss: 6.9218 - learning_rate: 1.0000e-04
# Epoch 23/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9242 - loss: 6.9079
# Epoch 23: val_accuracy improved from 0.92258 to 0.92387, saving model to /Users/hendriksippel/Documents/Repositories/cbs-mldl-drowsiness-detection/models/0_baseline_cnn/ckpt/afternoon run_checkpoint.model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 84s 2s/step - accuracy: 0.9241 - loss: 6.9081 - val_accuracy: 0.9239 - val_loss: 6.9190 - learning_rate: 1.0000e-04
# Epoch 24/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9273 - loss: 6.9115
# Epoch 24: val_accuracy did not improve from 0.92387
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 85s 2s/step - accuracy: 0.9273 - loss: 6.9114 - val_accuracy: 0.9213 - val_loss: 6.9175 - learning_rate: 1.0000e-04
# Epoch 25/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9274 - loss: 6.8999
# Epoch 25: val_accuracy did not improve from 0.92387
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.9274 - loss: 6.8999 - val_accuracy: 0.9213 - val_loss: 6.9150 - learning_rate: 1.0000e-04
# Epoch 26/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9218 - loss: 6.9112
# Epoch 26: val_accuracy did not improve from 0.92387
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.9218 - loss: 6.9110 - val_accuracy: 0.9226 - val_loss: 6.9120 - learning_rate: 1.0000e-04
# Epoch 27/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9290 - loss: 6.8904
# Epoch 27: val_accuracy did not improve from 0.92387
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.9291 - loss: 6.8903 - val_accuracy: 0.9239 - val_loss: 6.9097 - learning_rate: 1.0000e-04
# Epoch 28/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9307 - loss: 6.8915
# Epoch 28: val_accuracy did not improve from 0.92387
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.9307 - loss: 6.8914 - val_accuracy: 0.9239 - val_loss: 6.9063 - learning_rate: 1.0000e-04
# Epoch 29/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9217 - loss: 6.8962
# Epoch 29: val_accuracy did not improve from 0.92387
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.9218 - loss: 6.8961 - val_accuracy: 0.9239 - val_loss: 6.9052 - learning_rate: 1.0000e-04
# Epoch 30/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9302 - loss: 6.8872
# Epoch 30: val_accuracy did not improve from 0.92387
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.9303 - loss: 6.8870 - val_accuracy: 0.9239 - val_loss: 6.9029 - learning_rate: 1.0000e-04
# Epoch 31/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9366 - loss: 6.8718
# Epoch 31: val_accuracy did not improve from 0.92387
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.9365 - loss: 6.8718 - val_accuracy: 0.9226 - val_loss: 6.9020 - learning_rate: 1.0000e-04
# Epoch 32/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9275 - loss: 6.8836
# Epoch 32: val_accuracy did not improve from 0.92387
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.9277 - loss: 6.8834 - val_accuracy: 0.9239 - val_loss: 6.8992 - learning_rate: 1.0000e-04
# Epoch 33/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9287 - loss: 6.8809
# Epoch 33: val_accuracy did not improve from 0.92387
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.9288 - loss: 6.8807 - val_accuracy: 0.9226 - val_loss: 6.8964 - learning_rate: 1.0000e-04
# Epoch 34/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9380 - loss: 6.8738
# Epoch 34: val_accuracy improved from 0.92387 to 0.92645, saving model to /Users/hendriksippel/Documents/Repositories/cbs-mldl-drowsiness-detection/models/0_baseline_cnn/ckpt/afternoon run_checkpoint.model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.9380 - loss: 6.8738 - val_accuracy: 0.9265 - val_loss: 6.8960 - learning_rate: 5.0000e-05
# Epoch 35/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9440 - loss: 6.8515
# Epoch 35: val_accuracy improved from 0.92645 to 0.92774, saving model to /Users/hendriksippel/Documents/Repositories/cbs-mldl-drowsiness-detection/models/0_baseline_cnn/ckpt/afternoon run_checkpoint.model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 84s 2s/step - accuracy: 0.9439 - loss: 6.8516 - val_accuracy: 0.9277 - val_loss: 6.8961 - learning_rate: 5.0000e-05
# Epoch 36/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9317 - loss: 6.8720
# Epoch 36: val_accuracy did not improve from 0.92774
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.9319 - loss: 6.8718 - val_accuracy: 0.9277 - val_loss: 6.8952 - learning_rate: 5.0000e-05
# Epoch 37/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9388 - loss: 6.8796
# Epoch 37: val_accuracy did not improve from 0.92774
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.9389 - loss: 6.8792 - val_accuracy: 0.9277 - val_loss: 6.8937 - learning_rate: 5.0000e-05
# Epoch 38/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9355 - loss: 6.8609
# Epoch 38: val_accuracy did not improve from 0.92774
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.9356 - loss: 6.8608 - val_accuracy: 0.9277 - val_loss: 6.8925 - learning_rate: 5.0000e-05
# Epoch 39/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9380 - loss: 6.8611
# Epoch 39: val_accuracy improved from 0.92774 to 0.93032, saving model to /Users/hendriksippel/Documents/Repositories/cbs-mldl-drowsiness-detection/models/0_baseline_cnn/ckpt/afternoon run_checkpoint.model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.9381 - loss: 6.8610 - val_accuracy: 0.9303 - val_loss: 6.8915 - learning_rate: 5.0000e-05
# Epoch 40/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9233 - loss: 6.8736
# Epoch 40: val_accuracy did not improve from 0.93032
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.9235 - loss: 6.8734 - val_accuracy: 0.9290 - val_loss: 6.8903 - learning_rate: 5.0000e-05
# Epoch 41/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9361 - loss: 6.8631
# Epoch 41: val_accuracy did not improve from 0.93032
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.9361 - loss: 6.8629 - val_accuracy: 0.9290 - val_loss: 6.8896 - learning_rate: 5.0000e-05
# Epoch 42/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9350 - loss: 6.8595
# Epoch 42: val_accuracy did not improve from 0.93032
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.9351 - loss: 6.8594 - val_accuracy: 0.9290 - val_loss: 6.8882 - learning_rate: 5.0000e-05
# Epoch 43/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9370 - loss: 6.8618
# Epoch 43: val_accuracy did not improve from 0.93032
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - accuracy: 0.9372 - loss: 6.8615 - val_accuracy: 0.9290 - val_loss: 6.8873 - learning_rate: 5.0000e-05
# Epoch 44/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9415 - loss: 6.8554
# Epoch 44: val_accuracy did not improve from 0.93032
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.9415 - loss: 6.8553 - val_accuracy: 0.9303 - val_loss: 6.8858 - learning_rate: 5.0000e-05
# Epoch 45/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9435 - loss: 6.8578
# Epoch 45: val_accuracy did not improve from 0.93032
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 85s 2s/step - accuracy: 0.9434 - loss: 6.8576 - val_accuracy: 0.9290 - val_loss: 6.8856 - learning_rate: 5.0000e-05
# Epoch 46/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9357 - loss: 6.8593
# Epoch 46: val_accuracy did not improve from 0.93032
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - accuracy: 0.9358 - loss: 6.8592 - val_accuracy: 0.9303 - val_loss: 6.8840 - learning_rate: 5.0000e-05
# Epoch 47/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9393 - loss: 6.8572
# Epoch 47: val_accuracy did not improve from 0.93032
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.9394 - loss: 6.8570 - val_accuracy: 0.9277 - val_loss: 6.8832 - learning_rate: 5.0000e-05
# Epoch 48/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9449 - loss: 6.8527
# Epoch 48: val_accuracy did not improve from 0.93032
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.9450 - loss: 6.8524 - val_accuracy: 0.9277 - val_loss: 6.8820 - learning_rate: 5.0000e-05
# Epoch 49/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9416 - loss: 6.8387
# Epoch 49: val_accuracy did not improve from 0.93032
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 79s 2s/step - accuracy: 0.9416 - loss: 6.8386 - val_accuracy: 0.9265 - val_loss: 6.8812 - learning_rate: 5.0000e-05
# Epoch 50/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9388 - loss: 6.8436
# Epoch 50: val_accuracy did not improve from 0.93032
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.9389 - loss: 6.8436 - val_accuracy: 0.9277 - val_loss: 6.8805 - learning_rate: 2.5000e-05
# Epoch 51/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9404 - loss: 6.8441
# Epoch 51: val_accuracy did not improve from 0.93032
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.9404 - loss: 6.8438 - val_accuracy: 0.9290 - val_loss: 6.8800 - learning_rate: 2.5000e-05
# Epoch 52/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9346 - loss: 6.8459
# Epoch 52: val_accuracy did not improve from 0.93032
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.9347 - loss: 6.8457 - val_accuracy: 0.9290 - val_loss: 6.8799 - learning_rate: 2.5000e-05
# Epoch 53/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9503 - loss: 6.8318
# Epoch 53: val_accuracy did not improve from 0.93032
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.9502 - loss: 6.8317 - val_accuracy: 0.9277 - val_loss: 6.8795 - learning_rate: 2.5000e-05
# Epoch 54/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9339 - loss: 6.8547
# Epoch 54: val_accuracy did not improve from 0.93032
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.9340 - loss: 6.8545 - val_accuracy: 0.9290 - val_loss: 6.8791 - learning_rate: 2.5000e-05
# Epoch 55/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9453 - loss: 6.8370
# Epoch 55: val_accuracy did not improve from 0.93032
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 79s 2s/step - accuracy: 0.9453 - loss: 6.8370 - val_accuracy: 0.9290 - val_loss: 6.8786 - learning_rate: 2.5000e-05
# Epoch 56/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9368 - loss: 6.8406
# Epoch 56: val_accuracy did not improve from 0.93032
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.9369 - loss: 6.8405 - val_accuracy: 0.9303 - val_loss: 6.8780 - learning_rate: 2.5000e-05
# Epoch 57/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9498 - loss: 6.8347
# Epoch 57: val_accuracy did not improve from 0.93032
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 79s 2s/step - accuracy: 0.9498 - loss: 6.8346 - val_accuracy: 0.9290 - val_loss: 6.8779 - learning_rate: 2.5000e-05
# Epoch 58/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9423 - loss: 6.8452
# Epoch 58: val_accuracy did not improve from 0.93032
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 79s 2s/step - accuracy: 0.9423 - loss: 6.8451 - val_accuracy: 0.9277 - val_loss: 6.8779 - learning_rate: 2.5000e-05
# Epoch 59/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9439 - loss: 6.8345
# Epoch 59: val_accuracy did not improve from 0.93032
#
# Epoch 59: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 79s 2s/step - accuracy: 0.9439 - loss: 6.8345 - val_accuracy: 0.9277 - val_loss: 6.8775 - learning_rate: 2.5000e-05

# %%
# save the history
history_df = pd.DataFrame(history.history)
history_df['epoch'] = history.epoch
history_df.to_csv(history_file_path, index=False)

# %%
# load the best model
model.load_weights(ckpt_file_path)

# %%
# save the model
model.save(model_file_path)

# %%
plot_history(comment, history)
# Out:
# Best train_accuracy: 0.9503
# Best train_loss: 6.8285
# Best val_accuracy: 0.9303
# Best val_loss: 6.8775
# Last improvement at epoch: 39

# %%
evaluate_model(model, real_test_data)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.9392 - loss: 6.8769
# Test loss: 6.88734245300293
# Test accuracy: 0.929896891117096

# %%
real_train_data_augm = load_and_preprocess_images(realTrainingPath, batch_size=BATCH_SIZE, image_size=IMAGE_SIZE, seed=SEED, data_aug_rate=DATA_AUG_RATE, subset='training', validation_split=0.2, skip_preprocessing=True)
real_train_data_orig = load_and_preprocess_images(realTrainingPath, batch_size=BATCH_SIZE, image_size=IMAGE_SIZE, seed=SEED, skip_preprocessing=True)

plot_images(img_orig=real_train_data_augm, img_augm=real_train_data_orig)
# Out:
# Found 3876 files belonging to 2 classes.
# Using 3101 files for training.
# Found 3876 files belonging to 2 classes.
# 2024-07-12 17:48:05.995764: W tensorflow/core/kernels/data/cache_dataset_ops.cc:858] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.
# 2024-07-12 17:48:06.866820: W tensorflow/core/kernels/data/cache_dataset_ops.cc:858] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.
# 2024-07-12 17:48:06.879680: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
real_valid_data_skip_preprocessing = load_and_preprocess_images(realTrainingPath, batch_size=BATCH_SIZE, image_size=IMAGE_SIZE, seed=SEED, data_aug_rate=DATA_AUG_RATE, subset='validation', validation_split=0.2, skip_preprocessing=True)

plot_predictions(model=model, dataset=real_valid_data, dataset_visual=real_valid_data_skip_preprocessing)
# Out:
# Found 3876 files belonging to 2 classes.
# Using 775 files for validation.
# 2024-07-12 17:48:07.872605: W tensorflow/core/kernels/data/cache_dataset_ops.cc:858] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 725ms/step
# 2024-07-12 17:48:10.885368: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
