# %% [markdown]
# ## Basic Setup

# %%
import os
import sys
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.layers import Dense, Flatten, Input, Dropout, BatchNormalization
from keras.models import Sequential, Model
from keras.regularizers import l2
# Out:
# /Users/peterthyssen/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# Set the base path to the directory where src is located
base_path = '/Users/peterthyssen/Documents/GitHub/cbs-mldl-drowsiness-detection'

# Change the current working directory
os.chdir(base_path)

# Add the src directory to the system path
src_path = os.path.join(base_path, 'src')
sys.path.append(src_path)

# Now you can import the modules
from src.utils import load_and_preprocess_images, plot_images
from src.model_evaluation import evaluate_model, plot_history, plot_predictions

# %%
# set the random seeds to make sure that the results are reproducible
SEED = 1234
np.random.seed(SEED)
random.seed(SEED)
tf.random.set_seed(SEED)
keras.utils.set_random_seed(SEED)

# %%
model_name = '2_Finetuned_mlp'
repo_path = '/Users/peterthyssen/Documents/Repositories/cbs-mldl-drowsiness-detection'

syntheticDataPath = repo_path + '/data/Unity_Data_Test_Train'
syntheticTrainingPath = syntheticDataPath + '/TrainingSet'
syntheticTestPath = syntheticDataPath + '/TestSet'

realDataPath = repo_path + '/data/CEW_Data_Test_Train'
realTrainingPath = realDataPath + '/TrainingSet'
realTestPath = realDataPath + '/TestSet'

# %%
comment = "mlp_v14_07_24c"
model_file_path = repo_path + f"/models/{model_name}/weights/{comment}_model.keras"
ckpt_file_path = repo_path + f"/models/{model_name}/ckpt/{comment}_checkpoint.model.keras"
history_file_path = repo_path + f"/models/{model_name}/history/{comment}_history.csv"
assert not os.path.exists(ckpt_file_path), "Model already exists. Please change the comment."

# %%
# Hyperparameters
BATCH_SIZE = 64
IMAGE_SIZE = (224, 224)
INPUT_SHAPE = IMAGE_SIZE + (3,)

DATA_AUG_RATE = 0.1
EPOCHS = 100
REGULARIZATION = 0.01
DROPOUT = 0.3
LEARNING_RATE = 0.0001
LOSS_FUNCTION = 'binary_crossentropy'
OPTIMIZER = 'adam'

# %%
early_stop = EarlyStopping(monitor="val_accuracy", mode="max", patience=20, start_from_epoch=10)
checkpoint = ModelCheckpoint(ckpt_file_path, monitor="val_accuracy", mode="max", save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_lr=0.00001, verbose=1)

# %%
real_train_data = load_and_preprocess_images(realTrainingPath, batch_size=BATCH_SIZE, image_size=IMAGE_SIZE, seed=SEED, data_aug_rate=DATA_AUG_RATE, subset='training', validation_split=0.2)
real_valid_data = load_and_preprocess_images(realTrainingPath, batch_size=BATCH_SIZE, image_size=IMAGE_SIZE, seed=SEED, subset='validation', validation_split=0.2)
real_test_data = load_and_preprocess_images(realTestPath, batch_size=BATCH_SIZE, image_size=IMAGE_SIZE, seed=SEED, shuffle=False)
# Out:
# Found 3876 files belonging to 2 classes.
# Using 3101 files for training.
# Found 3876 files belonging to 2 classes.
# Using 775 files for validation.
# Found 970 files belonging to 2 classes.

# %%
synth_train_data = load_and_preprocess_images(syntheticTrainingPath, batch_size=BATCH_SIZE, image_size=IMAGE_SIZE, seed=SEED, data_aug_rate=DATA_AUG_RATE, subset='training', validation_split=0.2)
synth_valid_data = load_and_preprocess_images(syntheticTrainingPath, batch_size=BATCH_SIZE, image_size=IMAGE_SIZE, seed=SEED, subset='validation', validation_split=0.2)
synth_test_data = load_and_preprocess_images(syntheticTestPath, batch_size=BATCH_SIZE, image_size=IMAGE_SIZE, seed=SEED, shuffle=False)
# Out:
# Found 4743 files belonging to 2 classes.
# Using 3795 files for training.
# Found 4743 files belonging to 2 classes.
# Using 948 files for validation.
# Found 1187 files belonging to 2 classes.

# %%
# Define the MLP model
def build_mlp_model(input_shape):
    model = Sequential([
        Flatten(input_shape=input_shape),
        Dense(128, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    return model

# Build the model
model = build_mlp_model(INPUT_SHAPE)

# Define the path to the pre-trained model weights
pretrained_model_path = '/Users/peterthyssen/Documents/Repositories/cbs-mldl-drowsiness-detection/models/1_synthetic_mlp/weights/mlp_v14_07_24b_model.keras'

# Load pre-trained weights
model.load_weights(pretrained_model_path)

# Compile the model
model.compile(optimizer=OPTIMIZER, loss=LOSS_FUNCTION, metrics=['accuracy'])

# Print model summary to verify
model.summary()
# Out:
# /Users/peterthyssen/anaconda3/lib/python3.11/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 150528)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │    19,267,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,267,841 (73.50 MB)
#  Trainable params: 19,267,841 (73.50 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    real_train_data,
    validation_data=real_valid_data,
    epochs=EPOCHS,
    callbacks=[early_stop, checkpoint, reduce_lr]
    )
# Out:
# Epoch 1/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.5623 - loss: 31.0114
# Epoch 1: val_accuracy improved from -inf to 0.69806, saving model to /Users/peterthyssen/Documents/Repositories/cbs-mldl-drowsiness-detection/models/2_Finetuned_mlp/ckpt/mlp_v14_07_24c_checkpoint.model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 20s 404ms/step - accuracy: 0.5630 - loss: 30.6914 - val_accuracy: 0.6981 - val_loss: 2.4432 - learning_rate: 0.0010
# Epoch 2/100
# 48/49 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7121 - loss: 2.7891
# Epoch 2: val_accuracy improved from 0.69806 to 0.71484, saving model to /Users/peterthyssen/Documents/Repositories/cbs-mldl-drowsiness-detection/models/2_Finetuned_mlp/ckpt/mlp_v14_07_24c_checkpoint.model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 0.7119 - loss: 2.7792 - val_accuracy: 0.7148 - val_loss: 1.9991 - learning_rate: 0.0010
# Epoch 3/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7253 - loss: 1.8350
# Epoch 3: val_accuracy improved from 0.71484 to 0.74581, saving model to /Users/peterthyssen/Documents/Repositories/cbs-mldl-drowsiness-detection/models/2_Finetuned_mlp/ckpt/mlp_v14_07_24c_checkpoint.model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.7256 - loss: 1.8270 - val_accuracy: 0.7458 - val_loss: 1.0660 - learning_rate: 0.0010
# Epoch 4/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7813 - loss: 0.9589
# Epoch 4: val_accuracy improved from 0.74581 to 0.74839, saving model to /Users/peterthyssen/Documents/Repositories/cbs-mldl-drowsiness-detection/models/2_Finetuned_mlp/ckpt/mlp_v14_07_24c_checkpoint.model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.7813 - loss: 0.9602 - val_accuracy: 0.7484 - val_loss: 0.9955 - learning_rate: 0.0010
# Epoch 5/100
# 48/49 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8111 - loss: 0.7031
# Epoch 5: val_accuracy improved from 0.74839 to 0.75871, saving model to /Users/peterthyssen/Documents/Repositories/cbs-mldl-drowsiness-detection/models/2_Finetuned_mlp/ckpt/mlp_v14_07_24c_checkpoint.model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.8112 - loss: 0.7014 - val_accuracy: 0.7587 - val_loss: 0.9042 - learning_rate: 0.0010
# Epoch 6/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8113 - loss: 0.7271
# Epoch 6: val_accuracy improved from 0.75871 to 0.78710, saving model to /Users/peterthyssen/Documents/Repositories/cbs-mldl-drowsiness-detection/models/2_Finetuned_mlp/ckpt/mlp_v14_07_24c_checkpoint.model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.8115 - loss: 0.7262 - val_accuracy: 0.7871 - val_loss: 0.7144 - learning_rate: 0.0010
# Epoch 7/100
# 48/49 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8510 - loss: 0.5236
# Epoch 7: val_accuracy did not improve from 0.78710
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.8507 - loss: 0.5233 - val_accuracy: 0.7832 - val_loss: 0.8558 - learning_rate: 0.0010
# Epoch 8/100
# 48/49 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8403 - loss: 0.5997
# Epoch 8: val_accuracy did not improve from 0.78710
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.8405 - loss: 0.6011 - val_accuracy: 0.7729 - val_loss: 1.0235 - learning_rate: 0.0010
# Epoch 9/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8298 - loss: 0.7826
# Epoch 9: val_accuracy improved from 0.78710 to 0.80903, saving model to /Users/peterthyssen/Documents/Repositories/cbs-mldl-drowsiness-detection/models/2_Finetuned_mlp/ckpt/mlp_v14_07_24c_checkpoint.model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.8301 - loss: 0.7805 - val_accuracy: 0.8090 - val_loss: 0.8519 - learning_rate: 0.0010
# Epoch 10/100
# 48/49 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8595 - loss: 0.5932
# Epoch 10: val_accuracy did not improve from 0.80903
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.8596 - loss: 0.5952 - val_accuracy: 0.8090 - val_loss: 0.7363 - learning_rate: 0.0010
# Epoch 11/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8782 - loss: 0.4170
# Epoch 11: val_accuracy did not improve from 0.80903
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.8783 - loss: 0.4165 - val_accuracy: 0.8065 - val_loss: 0.6524 - learning_rate: 0.0010
# Epoch 12/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8590 - loss: 0.5255
# Epoch 12: val_accuracy improved from 0.80903 to 0.81548, saving model to /Users/peterthyssen/Documents/Repositories/cbs-mldl-drowsiness-detection/models/2_Finetuned_mlp/ckpt/mlp_v14_07_24c_checkpoint.model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.8592 - loss: 0.5243 - val_accuracy: 0.8155 - val_loss: 0.5533 - learning_rate: 0.0010
# Epoch 13/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8587 - loss: 0.5040
# Epoch 13: val_accuracy improved from 0.81548 to 0.82065, saving model to /Users/peterthyssen/Documents/Repositories/cbs-mldl-drowsiness-detection/models/2_Finetuned_mlp/ckpt/mlp_v14_07_24c_checkpoint.model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.8588 - loss: 0.5027 - val_accuracy: 0.8206 - val_loss: 0.6800 - learning_rate: 0.0010
# Epoch 14/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8758 - loss: 0.3441
# Epoch 14: val_accuracy improved from 0.82065 to 0.82323, saving model to /Users/peterthyssen/Documents/Repositories/cbs-mldl-drowsiness-detection/models/2_Finetuned_mlp/ckpt/mlp_v14_07_24c_checkpoint.model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.8760 - loss: 0.3435 - val_accuracy: 0.8232 - val_loss: 0.6318 - learning_rate: 0.0010
# Epoch 15/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8732 - loss: 0.4534
# Epoch 15: val_accuracy did not improve from 0.82323
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.8733 - loss: 0.4544 - val_accuracy: 0.8181 - val_loss: 0.9007 - learning_rate: 0.0010
# Epoch 16/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8781 - loss: 0.7668
# Epoch 16: val_accuracy improved from 0.82323 to 0.83097, saving model to /Users/peterthyssen/Documents/Repositories/cbs-mldl-drowsiness-detection/models/2_Finetuned_mlp/ckpt/mlp_v14_07_24c_checkpoint.model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.8781 - loss: 0.7664 - val_accuracy: 0.8310 - val_loss: 0.7512 - learning_rate: 0.0010
# Epoch 17/100
# 48/49 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8663 - loss: 0.9273
# Epoch 17: val_accuracy did not improve from 0.83097
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.8659 - loss: 0.9277 - val_accuracy: 0.8039 - val_loss: 0.8528 - learning_rate: 0.0010
# Epoch 18/100
# 48/49 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8795 - loss: 0.5030
# Epoch 18: val_accuracy did not improve from 0.83097
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8799 - loss: 0.5017 - val_accuracy: 0.8103 - val_loss: 0.7722 - learning_rate: 0.0010
# Epoch 19/100
# 48/49 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8906 - loss: 0.3177
# Epoch 19: val_accuracy improved from 0.83097 to 0.84000, saving model to /Users/peterthyssen/Documents/Repositories/cbs-mldl-drowsiness-detection/models/2_Finetuned_mlp/ckpt/mlp_v14_07_24c_checkpoint.model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.8906 - loss: 0.3173 - val_accuracy: 0.8400 - val_loss: 0.6382 - learning_rate: 0.0010
# Epoch 20/100
# 48/49 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8986 - loss: 0.2840
# Epoch 20: val_accuracy did not improve from 0.84000
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.8986 - loss: 0.2831 - val_accuracy: 0.8387 - val_loss: 0.6160 - learning_rate: 0.0010
# Epoch 21/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8994 - loss: 0.2952
# Epoch 21: val_accuracy did not improve from 0.84000
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.8995 - loss: 0.2952 - val_accuracy: 0.8245 - val_loss: 0.5393 - learning_rate: 0.0010
# Epoch 22/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9181 - loss: 0.2064
# Epoch 22: val_accuracy did not improve from 0.84000
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9181 - loss: 0.2063 - val_accuracy: 0.8374 - val_loss: 0.5109 - learning_rate: 0.0010
# Epoch 23/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9141 - loss: 0.2222
# Epoch 23: val_accuracy improved from 0.84000 to 0.84516, saving model to /Users/peterthyssen/Documents/Repositories/cbs-mldl-drowsiness-detection/models/2_Finetuned_mlp/ckpt/mlp_v14_07_24c_checkpoint.model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9142 - loss: 0.2218 - val_accuracy: 0.8452 - val_loss: 0.5143 - learning_rate: 0.0010
# Epoch 24/100
# 48/49 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9219 - loss: 0.2067
# Epoch 24: val_accuracy improved from 0.84516 to 0.85935, saving model to /Users/peterthyssen/Documents/Repositories/cbs-mldl-drowsiness-detection/models/2_Finetuned_mlp/ckpt/mlp_v14_07_24c_checkpoint.model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9221 - loss: 0.2055 - val_accuracy: 0.8594 - val_loss: 0.4978 - learning_rate: 0.0010
# Epoch 25/100
# 48/49 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9345 - loss: 0.1814
# Epoch 25: val_accuracy did not improve from 0.85935
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - accuracy: 0.9345 - loss: 0.1809 - val_accuracy: 0.8516 - val_loss: 0.5501 - learning_rate: 0.0010
# Epoch 26/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9393 - loss: 0.1675
# Epoch 26: val_accuracy did not improve from 0.85935
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9393 - loss: 0.1673 - val_accuracy: 0.8568 - val_loss: 0.5048 - learning_rate: 0.0010
# Epoch 27/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9335 - loss: 0.1605
# Epoch 27: val_accuracy did not improve from 0.85935
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9336 - loss: 0.1604 - val_accuracy: 0.8490 - val_loss: 0.5112 - learning_rate: 0.0010
# Epoch 28/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9376 - loss: 0.1604
# Epoch 28: val_accuracy did not improve from 0.85935
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9377 - loss: 0.1602 - val_accuracy: 0.8310 - val_loss: 0.5387 - learning_rate: 0.0010
# Epoch 29/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9372 - loss: 0.1460
# Epoch 29: val_accuracy did not improve from 0.85935
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9373 - loss: 0.1460 - val_accuracy: 0.8271 - val_loss: 0.5243 - learning_rate: 0.0010
# Epoch 30/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9424 - loss: 0.1449
# Epoch 30: val_accuracy did not improve from 0.85935
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9425 - loss: 0.1447 - val_accuracy: 0.8568 - val_loss: 0.5413 - learning_rate: 0.0010
# Epoch 31/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9160 - loss: 0.4411
# Epoch 31: val_accuracy did not improve from 0.85935
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9157 - loss: 0.4432 - val_accuracy: 0.8142 - val_loss: 0.5815 - learning_rate: 0.0010
# Epoch 32/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8952 - loss: 0.3326
# Epoch 32: val_accuracy did not improve from 0.85935
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.8953 - loss: 0.3329 - val_accuracy: 0.7742 - val_loss: 0.6611 - learning_rate: 0.0010
# Epoch 33/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9101 - loss: 0.2852
# Epoch 33: val_accuracy did not improve from 0.85935
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9102 - loss: 0.2846 - val_accuracy: 0.8581 - val_loss: 0.5152 - learning_rate: 0.0010
# Epoch 34/100
# 48/49 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9281 - loss: 0.2091
# Epoch 34: val_accuracy did not improve from 0.85935
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.9284 - loss: 0.2074 - val_accuracy: 0.8529 - val_loss: 0.4699 - learning_rate: 0.0010
# Epoch 35/100
# 48/49 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9535 - loss: 0.1145
# Epoch 35: val_accuracy improved from 0.85935 to 0.86968, saving model to /Users/peterthyssen/Documents/Repositories/cbs-mldl-drowsiness-detection/models/2_Finetuned_mlp/ckpt/mlp_v14_07_24c_checkpoint.model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.9534 - loss: 0.1145 - val_accuracy: 0.8697 - val_loss: 0.4495 - learning_rate: 5.0000e-04
# Epoch 36/100
# 48/49 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9510 - loss: 0.1107
# Epoch 36: val_accuracy did not improve from 0.86968
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9511 - loss: 0.1106 - val_accuracy: 0.8697 - val_loss: 0.4376 - learning_rate: 5.0000e-04
# Epoch 37/100
# 48/49 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9590 - loss: 0.0982
# Epoch 37: val_accuracy did not improve from 0.86968
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9591 - loss: 0.0981 - val_accuracy: 0.8697 - val_loss: 0.4472 - learning_rate: 5.0000e-04
# Epoch 38/100
# 48/49 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9609 - loss: 0.0933
# Epoch 38: val_accuracy improved from 0.86968 to 0.87742, saving model to /Users/peterthyssen/Documents/Repositories/cbs-mldl-drowsiness-detection/models/2_Finetuned_mlp/ckpt/mlp_v14_07_24c_checkpoint.model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9610 - loss: 0.0932 - val_accuracy: 0.8774 - val_loss: 0.4508 - learning_rate: 5.0000e-04
# Epoch 39/100
# 48/49 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9614 - loss: 0.0930
# Epoch 39: val_accuracy did not improve from 0.87742
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.9616 - loss: 0.0929 - val_accuracy: 0.8748 - val_loss: 0.4644 - learning_rate: 5.0000e-04
# Epoch 40/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9646 - loss: 0.0884
# Epoch 40: val_accuracy did not improve from 0.87742
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9646 - loss: 0.0883 - val_accuracy: 0.8774 - val_loss: 0.4557 - learning_rate: 5.0000e-04
# Epoch 41/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9672 - loss: 0.0836
# Epoch 41: val_accuracy did not improve from 0.87742
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9673 - loss: 0.0836 - val_accuracy: 0.8748 - val_loss: 0.4622 - learning_rate: 5.0000e-04
# Epoch 42/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9670 - loss: 0.0826
# Epoch 42: val_accuracy improved from 0.87742 to 0.87871, saving model to /Users/peterthyssen/Documents/Repositories/cbs-mldl-drowsiness-detection/models/2_Finetuned_mlp/ckpt/mlp_v14_07_24c_checkpoint.model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.9670 - loss: 0.0826 - val_accuracy: 0.8787 - val_loss: 0.4616 - learning_rate: 5.0000e-04
# Epoch 43/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9686 - loss: 0.0799
# Epoch 43: val_accuracy did not improve from 0.87871
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.9687 - loss: 0.0799 - val_accuracy: 0.8787 - val_loss: 0.4736 - learning_rate: 5.0000e-04
# Epoch 44/100
# 48/49 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9686 - loss: 0.0787
# Epoch 44: val_accuracy did not improve from 0.87871
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9686 - loss: 0.0787 - val_accuracy: 0.8684 - val_loss: 0.4754 - learning_rate: 5.0000e-04
# Epoch 45/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9692 - loss: 0.0782
# Epoch 45: val_accuracy did not improve from 0.87871
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9692 - loss: 0.0782 - val_accuracy: 0.8748 - val_loss: 0.4818 - learning_rate: 5.0000e-04
# Epoch 46/100
# 48/49 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9711 - loss: 0.0769
# Epoch 46: val_accuracy did not improve from 0.87871
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9711 - loss: 0.0768 - val_accuracy: 0.8735 - val_loss: 0.4800 - learning_rate: 5.0000e-04
# Epoch 47/100
# 48/49 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9728 - loss: 0.0723
# Epoch 47: val_accuracy did not improve from 0.87871
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9727 - loss: 0.0723 - val_accuracy: 0.8710 - val_loss: 0.4914 - learning_rate: 5.0000e-04
# Epoch 48/100
# 48/49 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9725 - loss: 0.0717
# Epoch 48: val_accuracy did not improve from 0.87871
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9725 - loss: 0.0717 - val_accuracy: 0.8761 - val_loss: 0.4878 - learning_rate: 5.0000e-04
# Epoch 49/100
# 48/49 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9700 - loss: 0.0705
# Epoch 49: val_accuracy did not improve from 0.87871
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9700 - loss: 0.0704 - val_accuracy: 0.8735 - val_loss: 0.5011 - learning_rate: 5.0000e-04
# Epoch 50/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9720 - loss: 0.0692
# Epoch 50: val_accuracy did not improve from 0.87871
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9720 - loss: 0.0692 - val_accuracy: 0.8710 - val_loss: 0.5007 - learning_rate: 5.0000e-04
# Epoch 51/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9740 - loss: 0.0680
# Epoch 51: val_accuracy did not improve from 0.87871
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9739 - loss: 0.0680 - val_accuracy: 0.8606 - val_loss: 0.5157 - learning_rate: 5.0000e-04
# Epoch 52/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9767 - loss: 0.0663
# Epoch 52: val_accuracy did not improve from 0.87871
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9767 - loss: 0.0663 - val_accuracy: 0.8697 - val_loss: 0.5034 - learning_rate: 5.0000e-04
# Epoch 53/100
# 48/49 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9743 - loss: 0.0622
# Epoch 53: val_accuracy did not improve from 0.87871
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9744 - loss: 0.0622 - val_accuracy: 0.8710 - val_loss: 0.5079 - learning_rate: 2.5000e-04
# Epoch 54/100
# 48/49 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9762 - loss: 0.0625
# Epoch 54: val_accuracy did not improve from 0.87871
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9762 - loss: 0.0625 - val_accuracy: 0.8723 - val_loss: 0.5137 - learning_rate: 2.5000e-04
# Epoch 55/100
# 48/49 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9770 - loss: 0.0621
# Epoch 55: val_accuracy did not improve from 0.87871
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9770 - loss: 0.0621 - val_accuracy: 0.8723 - val_loss: 0.5176 - learning_rate: 2.5000e-04
# Epoch 56/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9765 - loss: 0.0612
# Epoch 56: val_accuracy did not improve from 0.87871
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9766 - loss: 0.0612 - val_accuracy: 0.8697 - val_loss: 0.5342 - learning_rate: 2.5000e-04
# Epoch 57/100
# 48/49 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9757 - loss: 0.0628
# Epoch 57: val_accuracy did not improve from 0.87871
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.9757 - loss: 0.0628 - val_accuracy: 0.8735 - val_loss: 0.5215 - learning_rate: 2.5000e-04
# Epoch 58/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9781 - loss: 0.0600
# Epoch 58: val_accuracy did not improve from 0.87871
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9781 - loss: 0.0600 - val_accuracy: 0.8710 - val_loss: 0.5369 - learning_rate: 2.5000e-04
# Epoch 59/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9776 - loss: 0.0603
# Epoch 59: val_accuracy did not improve from 0.87871
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9776 - loss: 0.0603 - val_accuracy: 0.8684 - val_loss: 0.5289 - learning_rate: 2.5000e-04
# Epoch 60/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9780 - loss: 0.0583
# Epoch 60: val_accuracy did not improve from 0.87871
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9780 - loss: 0.0584 - val_accuracy: 0.8697 - val_loss: 0.5406 - learning_rate: 2.5000e-04
# Epoch 61/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9777 - loss: 0.0590
# Epoch 61: val_accuracy did not improve from 0.87871
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.9777 - loss: 0.0590 - val_accuracy: 0.8658 - val_loss: 0.5318 - learning_rate: 2.5000e-04
# Epoch 62/100
# 48/49 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9787 - loss: 0.0578
# Epoch 62: val_accuracy did not improve from 0.87871
#
# Epoch 62: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.9787 - loss: 0.0578 - val_accuracy: 0.8671 - val_loss: 0.5416 - learning_rate: 2.5000e-04

# %%
# Ensure the directory exists
os.makedirs(os.path.dirname(history_file_path), exist_ok=True)

# save the history
history_df = pd.DataFrame(history.history)
history_df['epoch'] = history.epoch
history_df.to_csv(history_file_path, index=False)

# %%
# load the best model
model.load_weights(ckpt_file_path)

# %%
# Ensure the directory exists
os.makedirs(os.path.dirname(model_file_path), exist_ok=True)

# save the model
model.save(model_file_path)

# %%
plot_history(comment, history)
# Out:
# Best train_accuracy: 0.9784
# Best train_loss: 0.058
# Best val_accuracy: 0.8787
# Best val_loss: 0.4376
# Last improvement at epoch: 42

# %%
evaluate_model(model, real_test_data)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8733 - loss: 0.4433
# Test loss: 0.4110649824142456
# Test accuracy: 0.8814433217048645
